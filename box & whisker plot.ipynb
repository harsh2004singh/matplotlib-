# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import random
x = np.random.randint(-100,500,(200))

# %%
x
# Out:
# array([293, 368,  -5, 436, 325, 198, 304, 468, 290, -97, 352, 375, 139,
#         11,  86, 496, 185, 122,  66, 405, 411, 237, 342, 263,  -1,  48,
#        -25, 115, 411, 243, 458, 191, 256, -53, -16,  40,  78, 327,  17,
#         39, 296,  -5,  88, 119,  60, 135, 469, 366, 309, 469, -42, 400,
#        184, 402, -67, 290, 374,  -8,  56, 436, 261, 483, -49,  95, 168,
#         69, 329, 243, 232, 161, 115, 114, 275, 467, 345, 259, 411, 349,
#        166, 195, 228, 135, 165,   3,  80, 112, 260, 438, 335, 143, 157,
#        -69, -33, 269,  88, 129,  71, -27, 297, 132,   9, 439, 468, 473,
#        128,  -1, 214, 286, 408, -39, 104, 351, 366, 109, 360, 276, 496,
#        -84, 155,  36, 146, 335, 331,   1, 499, 234,  -4, -86, 321, 331,
#        -20, 403, 298, 241,  -5, 190, 460,  37, 304, 135, 267, -93, 363,
#        463, 320, 213, 201, 469,  10, 404, 178, 414, 213, 310, 146,  53,
#         -4, -40, 389, -92, 366,  42, 292, 293, 126,  47, 237, 447, 341,
# ...

# %%
x =[293, 368,  -5, 436, 325, 198, 304, 468, 290, -97, 352, 375, 139,
        11,  86, 496, 185, 122,  66, 405, 411, 237, 342, 263,  -1,  48,
       -25, 115, 411, 243, 458, 191, 256, -53, -16,  40,  78, 327,  17,
        39, 296,  -5,  88, 119,  60, 135, 469, 366, 309, 469, -42, 400,
       184, 402, -67, 290, 374,  -8,  56, 436, 261, 483, -49,  95, 168,
        69, 329, 243, 232, 161, 115, 114, 275, 467, 345, 259, 411, 349,
       166, 195, 228, 135, 165,   3,  80, 112, 260, 438, 335, 143, 157,
       -69, -33, 269,  88, 129,  71, -27, 297, 132,   9, 439, 468, 473,
       128,  -1, 214, 286, 408, -39, 104, 351, 366, 109, 360, 276, 496,
       -84, 155,  36, 146, 335, 331,   1, 499, 234,  -4, -86, 321, 331,
       -20, 403, 298, 241,  -5, 190, 460,  37, 304, 135, 267, -93, 363,
       463, 320, 213, 201, 469,  10, 404, 178, 414, 213, 310, 146,  53,
        -4, -40, 389, -92, 366,  42, 292, 293, 126,  47, 237, 447, 341,
       222, 497, 259, 287, 334, 144, 406,  73, 218, 361, 148, -80, 109,
       492, 499, 377, 288, -71, 180, 318, 241, 138, 116,  39,  96,  66,
       197, 398, 375, 442, 330,800,-345]

# %%
plt.boxplot(x)
plt.show()

# %%
plt.boxplot(x,notch=True)
plt.show()

# %%
plt.boxplot(x,vert=False)
plt.show()

# %%
plt.boxplot(x,widths=0.5)
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'])
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],patch_artist=True)
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],patch_artist=True,showmeans=True)
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],patch_artist=True,whis=3.5)
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],patch_artist=True,sym="g+")
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],patch_artist=True,sym=" ")
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],boxprops=dict(color="r"))
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],boxprops=dict(color="r"),capprops=dict(color="g"))
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],boxprops=dict(color="r"),capprops=dict(color="g"),whiskerprops=dict(color="r"))
plt.show()

# %%
plt.boxplot(x,labels=['boxplot'],boxprops=dict(color="r"),capprops=dict(color="g"),whiskerprops=dict(color="r"),
            flierprops=dict(markeredgecolor = "y"))
plt.show()

# %%
y = np.random.randint(-50,400,(200))

# %%
plt.boxplot(x,labels=['boxplot'],boxprops=dict(color="r"),capprops=dict(color="g"),whiskerprops=dict(color="r"),
            flierprops=dict(markeredgecolor = "y"))
plt.boxplot(y,labels=['boxplot'])
plt.show()
