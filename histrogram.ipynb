# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import random

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [47 30 48 28 24 42 58 59 34 32 45 45 13 34 32 25 19 33 32 44 42 21 36 56
#  58 37 32 29 11 55 36 32 52 49 43 40 20 13 22 29 29 13 26 10 51 47 51 21
#  37 45]

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
plt.hist(no)
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
plt.hist(no,color ="g",edgecolor ='r')
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l)
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor ='r')
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,cumulative=-1)
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,bottom=10)
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,align='left')
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()
# it is a solid histrogram

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,histtype="step")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,histtype="stepfilled")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,histtype="barstacked")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,histtype="bar")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,orientation="horizontal")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,rwidth=0.8)
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,label="python")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")
plt.legend()
plt.show()

# %%
no =[47,30, 48, 28, 24, 42, 58, 59, 34, 32, 45, 45, 13, 34, 32, 25, 19, 33, 32, 44, 42, 21, 36, 56,58, 37, 32, 29, 11, 55,
     36, 32, 52, 49, 43, 40, 20, 13, 22, 29, 29, 13, 26, 10, 51, 47, 51, 21,37, 45,]
l=[10,20,30,40,50,60]
plt.hist(no,color ="g",edgecolor ='r',bins =l,label="python")
plt.title('spend a days')
plt.xlabel("amount")
plt.ylabel("days")

plt.legend()
plt.show()
